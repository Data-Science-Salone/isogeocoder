# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
def subregions(continent = None,level=None,sep=None):
    countries_df = pd.read_csv('countries_iso.csv')
    countries = countries_df.drop_duplicates(subset=['Alpha-3 code'])
    
    if continent == None:
        df = countries
    else:
        continent = continent.capitalize()
        df = countries[countries['Continet'].str.capitalize()==continent]
    df = df.drop_duplicates(subset=['Subregions'])
    zfill = len(str(df['M49code_Subregions'].max()))
    zfill_c = len(str(df['M49code_continent'].max()))
    if level != None and sep == None:
        df['Subregions_code'] = df['M49code_continent'].astype(str).str.zfill(zfill)+'-'+df['M49code_Subregions'].astype(str).str.zfill(zfill)
    elif sep != None:
         df['Subregions_code'] = df['M49code_continent'].astype(str).str.zfill(zfill)+sep+df['M49code_Subregions'].astype(str).str.zfill(zfill)
    else:
        df['Subregions_code'] = df['M49code_Subregions'].astype(str).str.zfill(zfill)
    df['Continent_code'] = df['M49code_continent'].astype(str).str.zfill(zfill)
    df = df[['Continet','M49code_continent','Continent_code','Subregions','M49code_Subregions','Subregions_code']]
    return df

# %%
sub = subregions(continent='africa',level=2,sep="!")
sub
# Out:
#     Continet  M49code_continent Continent_code       Subregions  \
# 42    Africa                  2             02  Northern Africa
# 59    Africa                  2             02    Middle Africa
# 163   Africa                  2             02   Western Africa
# 185   Africa                  2             02  Southern Africa
# 190   Africa                  2             02   Eastern Africa
#
#      M49code_Subregions Subregions_code
# 42                   15           02!15
# 59                   17           02!17
# 163                  11           02!11
# 185                  18           02!18
# 190                  14           02!14

# %%
def continents():
    countries_df = pd.read_csv('countries_iso.csv')
    countries = countries_df.drop_duplicates(subset=['Alpha-3 code'])
    df = countries.drop_duplicates(subset=['Continet'])
    df = df[['Continet','M49code_continent']]
    zfill = len(str(df['M49code_continent'].max()))
    df['Continet_code'] = df['M49code_continent'].astype(str).str.zfill(zfill)
    return df

# %%
continents()
# Out:
#     Continet  M49code_continent Continet_code
# 0       Asia                142           142
# 9     Europe                150           150
# 42    Africa                  2           002
# 49   Oceania                  9           009
# 68  Americas                 10           010

# %%
def countries(continent=None,level=None,sep=None):
    countries_df = pd.read_csv('countries_iso.csv')
    countries = countries_df.drop_duplicates(subset=['Alpha-3 code'])
    
    if continent == None:
        df = countries
    else:
        continent = continent.capitalize()
        df = countries[countries['Continet'].str.capitalize()==continent]
    df = df.drop_duplicates(subset=['Country'])
    zfill = len(str(df['M49code_Subregions'].max()))
    zfillc = len(str(df['M49code_continent'].max()))
    zfill_country = len(str(df['M49Code_country'].max()))
    if (level != None or level !=1) and sep == None:
        df['Continent_code'] = df['M49code_continent'].astype(str).str.zfill(zfillc)
        df['Subregions_code'] = df['M49code_continent'].astype(str).str.zfill(zfillc)+'-'+df['M49code_Subregions'].astype(str).str.zfill(zfill)
        df['country_code'] = df['M49code_Subregions'].astype(str).str.zfill(zfill)+'-'+df['M49Code_country'].astype(str).str.zfill(zfill)
    if level == 1 and sep == None:
        df['Continent_code'] = df['M49code_continent'].astype(str).str.zfill(zfillc)
        df['Subregions_code'] = df['M49code_continent'].astype(str).str.zfill(zfillc)+'-'+df['M49code_Subregions'].astype(str).str.zfill(zfill)
        df['country_code'] = df['Subregions_code'].astype(str).str.zfill(zfill)+'-'+df['M49Code_country'].astype(str).str.zfill(zfill)
    elif level == 2 and sep == None:
        df['Continent_code'] = df['M49code_continent'].astype(str).str.zfill(zfillc)
        df['Subregions_code'] = df['M49code_continent'].astype(str).str.zfill(zfillc)+'-'+df['M49code_Subregions'].astype(str).str.zfill(zfill)
        df['country_code'] = df['M49code_Subregions'].astype(str).str.zfill(zfill)+'-'+df['M49Code_country'].astype(str).str.zfill(zfill)
  
    elif sep != None:
        df['Continent_code'] = df['M49code_continent'].astype(str).str.zfill(zfillc)
        df['Subregions_code'] = df['M49code_continent'].astype(str).str.zfill(zfillc)+sep+df['M49code_Subregions'].astype(str).str.zfill(zfill)
        df['country_code'] = df['M49code_Subregions'].astype(str).str.zfill(zfill)+sep+df['M49Code_country'].astype(str).str.zfill(zfill)   
    else:
        df['Subregions_code'] = df['M49code_Subregions'].astype(str).str.zfill(zfill)
        df['country_code'] = df['M49Code_country'].astype(str).str.zfill(zfill_country)    
        df['Continent_code'] = df['M49code_continent'].astype(str).str.zfill(zfillc)
    
    df = df[['Continet','M49code_continent','Continent_code','Subregions','M49code_Subregions','Subregions_code','Country','Alpha-3 code','M49Code_country','country_code']]
    return df

# %%
countries('Africa')
# Out:
#     Continet  M49code_continent Continent_code       Subregions  \
# 42    Africa                  2              2  Northern Africa
# 43    Africa                  2              2  Northern Africa
# 44    Africa                  2              2  Northern Africa
# 45    Africa                  2              2  Northern Africa
# 46    Africa                  2              2  Northern Africa
# 47    Africa                  2              2  Northern Africa
# 48    Africa                  2              2  Northern Africa
# 59    Africa                  2              2    Middle Africa
# 60    Africa                  2              2    Middle Africa
# 61    Africa                  2              2    Middle Africa
# 62    Africa                  2              2    Middle Africa
# 63    Africa                  2              2    Middle Africa
# 64    Africa                  2              2    Middle Africa
# 65    Africa                  2              2    Middle Africa
# 66    Africa                  2              2    Middle Africa
# 67    Africa                  2              2    Middle Africa
# 163   Africa                  2              2   Western Africa
# 164   Africa                  2              2   Western Africa
# 165   Africa                  2              2   Western Africa
# 166   Africa                  2              2   Western Africa
# 167   Africa                  2              2   Western Africa
# 168   Africa                  2              2   Western Africa
# 169   Africa                  2              2   Western Africa
# 170   Africa                  2              2   Western Africa
# 171   Africa                  2              2   Western Africa
# 172   Africa                  2              2   Western Africa
# 173   Africa                  2              2   Western Africa
# 174   Africa                  2              2   Western Africa
# 175   Africa                  2              2   Western Africa
# 176   Africa                  2              2   Western Africa
# 177   Africa                  2              2   Western Africa
# 178   Africa                  2              2   Western Africa
# 179   Africa                  2              2   Western Africa
# 185   Africa                  2              2  Southern Africa
# 186   Africa                  2              2  Southern Africa
# 187   Africa                  2              2  Southern Africa
# 188   Africa                  2              2  Southern Africa
# 189   Africa                  2              2  Southern Africa
# 190   Africa                  2              2   Eastern Africa
# 191   Africa                  2              2   Eastern Africa
# 192   Africa                  2              2   Eastern Africa
# 193   Africa                  2              2   Eastern Africa
# 194   Africa                  2              2   Eastern Africa
# 195   Africa                  2              2   Eastern Africa
# 196   Africa                  2              2   Eastern Africa
# 197   Africa                  2              2   Eastern Africa
# 198   Africa                  2              2   Eastern Africa
# 199   Africa                  2              2   Eastern Africa
# 200   Africa                  2              2   Eastern Africa
# 201   Africa                  2              2   Eastern Africa
# 202   Africa                  2              2   Eastern Africa
# 203   Africa                  2              2   Eastern Africa
# 204   Africa                  2              2   Eastern Africa
# 205   Africa                  2              2   Eastern Africa
# 206   Africa                  2              2   Eastern Africa
# 207   Africa                  2              2   Eastern Africa
# 208   Africa                  2              2   Eastern Africa
# 209   Africa                  2              2   Eastern Africa
# 210   Africa                  2              2   Eastern Africa
# 211   Africa                  2              2   Eastern Africa
#
#      M49code_Subregions Subregions_code                           Country  \
# 42                   15              15                           Algeria
# 43                   15              15                             Egypt
# 44                   15              15                             Libya
# 45                   15              15                           Morocco
# 46                   15              15                             Sudan
# 47                   15              15                           Tunisia
# 48                   15              15                    Western Sahara
# 59                   17              17                            Angola
# 60                   17              17                          Cameroon
# 61                   17              17          Central African Republic
# 62                   17              17                              Chad
# 63                   17              17                             Congo
# 64                   17              17  Democratic Republic of the Congo
# 65                   17              17                 Equatorial Guinea
# 66                   17              17                             Gabon
# 67                   17              17             Sao Tome and Principe
# 163                  11              11                             Benin
# 164                  11              11                      Burkina Faso
# 165                  11              11                        Cabo Verde
# 166                  11              11                       Ivory Coast
# 167                  11              11                            Gambia
# 168                  11              11                             Ghana
# 169                  11              11                            Guinea
# 170                  11              11                     Guinea-Bissau
# 171                  11              11                           Liberia
# 172                  11              11                              Mali
# 173                  11              11                        Mauritania
# 174                  11              11                             Niger
# 175                  11              11                           Nigeria
# 176                  11              11                      Saint Helena
# 177                  11              11                           Senegal
# 178                  11              11                      Sierra Leone
# 179                  11              11                              Togo
# 185                  18              18                          Botswana
# 186                  18              18                          Eswatini
# 187                  18              18                           Lesotho
# 188                  18              18                           Namibia
# 189                  18              18                      South Africa
# 190                  14              14    British Indian Ocean Territory
# 191                  14              14                           Burundi
# 192                  14              14                           Comoros
# 193                  14              14                          Djibouti
# 194                  14              14                           Eritrea
# 195                  14              14                          Ethiopia
# 196                  14              14       French Southern Territories
# 197                  14              14                             Kenya
# 198                  14              14                        Madagascar
# 199                  14              14                            Malawi
# 200                  14              14                         Mauritius
# 201                  14              14                           Mayotte
# 202                  14              14                        Mozambique
# 203                  14              14                           Réunion
# 204                  14              14                            Rwanda
# 205                  14              14                        Seychelles
# 206                  14              14                           Somalia
# 207                  14              14                       South Sudan
# 208                  14              14                            Uganda
# 209                  14              14       United Republic of Tanzania
# 210                  14              14                            Zambia
# 211                  14              14                          Zimbabwe
#
#     Alpha-3 code  M49Code_country country_code
# 42           DZA               12          012
# 43           EGY              818          818
# 44           LBY              434          434
# 45           MAR              504          504
# 46           SDN              729          729
# 47           TUN              788          788
# 48           ESH              732          732
# 59           AGO               24          024
# 60           CMR              120          120
# 61           CAF              140          140
# 62           TCD              148          148
# 63           COG              178          178
# 64           COD              180          180
# 65           GNQ              226          226
# 66           GAB              266          266
# 67           STP              678          678
# 163          BEN              204          204
# 164          BFA              854          854
# 165          CPV              132          132
# 166          CIV              384          384
# 167          GMB              270          270
# 168          GHA              288          288
# 169          GIN              324          324
# 170          GNB              624          624
# 171          LBR              430          430
# 172          MLI              466          466
# 173          MRT              478          478
# 174          NER              562          562
# 175          NGA              566          566
# 176          SHN              654          654
# 177          SEN              686          686
# 178          SLE              694          694
# 179          TGO              768          768
# 185          BWA               72          072
# 186          SWZ              748          748
# 187          LSO              426          426
# 188          NAM              516          516
# 189          ZAF              710          710
# 190          IOT               86          086
# 191          BDI              108          108
# 192          COM              174          174
# 193          DJI              262          262
# 194          ERI              232          232
# 195          ETH              231          231
# 196          ATF              260          260
# 197          KEN              404          404
# 198          MDG              450          450
# 199          MWI              454          454
# 200          MUS              480          480
# 201          MYT              175          175
# 202          MOZ              508          508
# 203          REU              638          638
# 204          RWA              646          646
# 205          SYC              690          690
# 206          SOM              706          706
# 207          SSD              728          728
# 208          UGA              800          800
# 209          TZA              834          834
# 210          ZMB              894          894
# 211          ZWE              716          716

# %%
countries()
# Out:
#     Continet  M49code_continent Continent_code     Subregions  \
# 0       Asia                142            142  Southern Asia
# 1       Asia                142            142  Southern Asia
# 2       Asia                142            142  Southern Asia
# 3       Asia                142            142  Southern Asia
# 4       Asia                142            142  Southern Asia
# ..       ...                ...            ...            ...
# 243     Asia                142            142   Central Asia
# 244     Asia                142            142   Central Asia
# 245     Asia                142            142   Central Asia
# 246     Asia                142            142   Central Asia
# 247     Asia                142            142   Central Asia
#
#      M49code_Subregions Subregions_code                     Country  \
# 0                    34             034                 Afghanistan
# 1                    34             034                  Bangladesh
# 2                    34             034                      Bhutan
# 3                    34             034                       India
# 4                    34             034  Iran (Islamic Republic of)
# ..                  ...             ...                         ...
# 243                 143             143                  Kazakhstan
# 244                 143             143                  Kyrgyzstan
# 245                 143             143                  Tajikistan
# 246                 143             143                Turkmenistan
# 247                 143             143                  Uzbekistan
#
#     Alpha-3 code  M49Code_country country_code
# 0            AFG                4          004
# 1            BGD               50          050
# 2            BTN               64          064
# 3            IND              356          356
# 4            IRN              364          364
# ..           ...              ...          ...
# 243          KAZ              398          398
# 244          KGZ              417          417
# 245          TJK              762          762
# 246          TKM              795          795
# 247          UZB              860          860
#
# [248 rows x 10 columns]

# %%
iso.head(5)
# Out:
#   Subdivision category 3166-2 code Subdivision name Local variant  \
# 0             province     AF-BDS*       Badakhshān           NaN
# 1             province     AF-BDS*       Badakhshān           NaN
# 2             province     AF-BGL*          Baghlān           NaN
# 3             province     AF-BGL*          Baghlān           NaN
# 4             province     AF-BAL*            Balkh           NaN
#
#   Language code Romanization system Parent subdivision
# 0            fa       BGN/PCGN 2007                NaN
# 1            ps       BGN/PCGN 2007                NaN
# 2            fa       BGN/PCGN 2007                NaN
# 3            ps       BGN/PCGN 2007                NaN
# 4            fa       BGN/PCGN 2007                NaN

# %%
iso.columns
# Out:
# Index(['Subdivision category', '3166-2 code', 'Subdivision name',
#        'Local variant', 'Language code', 'Romanization system',
#        'Parent subdivision'],
#       dtype='object')

# %%
def country(country =None):
    countries_df = pd.read_csv('countries_iso.csv')
    countries = pd.read_csv('countries.csv')
    countries_sub = pd.read_csv('countryiso.csv')
    iso = pd.read_csv('sub_div_countries.csv')
    iso_df.loc['subdiv-code'] = iso_df['3166-2 code'].str.replace('*', '')
    iso_df[['Alpha-2 code','sub-code']] = iso_df['3166-2 code'].str.replace('*', '').str.split('-', expand = True)
    country_df = pd.merge(countries_sub,iso_df,on='Alpha-2 code',how='inner')
    countrydf = pd.merge(countries,country_df,on='Alpha-3 code',how='inner')
    zfill_country = len(str(countries_df['M49Code_country'].max()))
    zfill = len(str(countrydf['M49code_Subregions'].max()))
    zfillc = len(str(countrydf['M49code_continent'].max()))
    countrydf['Subregions_code'] = countrydf['M49code_Subregions'].astype(str).str.zfill(zfill)
    countrydf['country_code'] = countrydf['M49Code_country'].astype(str).str.zfill(zfill_country)    
    countrydf['Continent_code'] = countrydf['M49code_continent'].astype(str).str.zfill(zfillc)
    countrydf = countrydf[['Continet','M49code_continent','Continent_code','Subregions','M49code_Subregions','Subregions_code','Country','M49Code_country','country_code','Alpha-3 code','Alpha-2 code','Subdivision category',
           'Subdivision name', '3166-2 code', 'sub-code']]

    if country == None:
            df = countrydf
    else:
            country = country.capitalize()
            df = countrydf[(countrydf['Country'].str.capitalize()==country) | (countrydf['Alpha-2 code'].str.upper()==country.upper()) | (countrydf['Subregions'].str.capitalize()==country.capitalize()) | (countrydf['Continet'].str.capitalize()==country.capitalize())]
    df = df.drop_duplicates(subset=['3166-2 code'])
    return df

# %%
countries_df = pd.read_csv('countries_iso.csv')
countries = pd.read_csv('countries.csv')
countries_sub = pd.read_csv('countryiso.csv')

# %%
country('sl')
# Out:
#      Continet  M49code_continent Continent_code      Subregions  \
# 4329   Africa                  2            002  Western Africa
# 4330   Africa                  2            002  Western Africa
# 4331   Africa                  2            002  Western Africa
# 4332   Africa                  2            002  Western Africa
# 4333   Africa                  2            002  Western Africa
#
#       M49code_Subregions Subregions_code       Country  M49Code_country  \
# 4329                  11             011  Sierra Leone              694
# 4330                  11             011  Sierra Leone              694
# 4331                  11             011  Sierra Leone              694
# 4332                  11             011  Sierra Leone              694
# 4333                  11             011  Sierra Leone              694
#
#      country_code Alpha-3 code Alpha-2 code Subdivision category  \
# 4329          694          SLE           SL             province
# 4330          694          SLE           SL             province
# 4331          694          SLE           SL             province
# 4332          694          SLE           SL             province
# 4333          694          SLE           SL                 area
#
#              Subdivision name 3166-2 code sub-code
# 4329                  Eastern        SL-E        E
# 4330            North Western       SL-NW       NW
# 4331                 Northern        SL-N        N
# 4332                 Southern        SL-S        S
# 4333  Western Area (Freetown)        SL-W        W

# %%
country('Northern Africa').head(2)
# Out:
#      Continet  M49code_continent Continent_code       Subregions  \
# 1733   Africa                  2            002  Northern Africa
# 1734   Africa                  2            002  Northern Africa
#
#       M49code_Subregions Subregions_code  Country  M49Code_country  \
# 1733                  15             015  Algeria               12
# 1734                  15             015  Algeria               12
#
#      country_code Alpha-3 code Alpha-2 code Subdivision category  \
# 1733          012          DZA           DZ             province
# 1734          012          DZA           DZ             province
#
#      Subdivision name 3166-2 code sub-code
# 1733            Adrar       DZ-01       01
# 1734            Alger       DZ-16       16

# %%
ct =  country()

# %%
def uniqueid(df,level_four_df,column):
        #name of code columns
        zfill = len(str(df.shape[0]))
        prevoius_level = list(level_four_df.columns)
        #Name the coded column in the dataframe
        level_code_col = '{}_code'.format(column)
        df[level_code_col] = (df.index+1).astype(str).str.zfill(zfill)
        columns = [pcolumn for pcolumn in level_four_df if "code" not in pcolumn]
        columns.append(column)
        columns.append(level_code_col)
        return df

# %%
couti = countries[['Country','Alpha-3 code']]

# %%
offices= uniqueid(couti,ct,'country_office')

# %%
def gencode(level_df,uniqueid_df,cat_df=None,level_column=None,uniqueid_column=None,columns=None,title=None,sep=None):
        column = columns
        
        df = pd.merge(level_df,uniqueid_df,on=column,how='inner')
        if cat_df is not None:
            cat_df_col_ = cat_df.columns[0]
            df_final = pd.merge(df,cat_df,on=cat_df_col_,how='inner')
        else:
            df_final = df
        
        if sep is not None:
            df_final[title] = df_final[level_column].astype(str)+sep+df_final[uniqueid_column].astype(str)
        else:
            cat_df_col = cat_df_col_
            df_final[title] = df_final[level_column].astype(str)+df_final[uniqueid_column].astype(str)
        return df_final

# %%
gencode(ct,offices,level_column='country_code',uniqueid_column='country_office_code',columns=['Country','Alpha-3 code'],title='Office_id',sep='-')
# Out:
#      Continet  M49code_continent Continent_code     Subregions  \
# 0        Asia                142            142  Southern Asia
# 1        Asia                142            142  Southern Asia
# 2        Asia                142            142  Southern Asia
# 3        Asia                142            142  Southern Asia
# 4        Asia                142            142  Southern Asia
# ...       ...                ...            ...            ...
# 4829     Asia                142            142   Central Asia
# 4830     Asia                142            142   Central Asia
# 4831     Asia                142            142   Central Asia
# 4832     Asia                142            142   Central Asia
# 4833     Asia                142            142   Central Asia
#
#       M49code_Subregions Subregions_code      Country  M49Code_country  \
# 0                     34             034  Afghanistan                4
# 1                     34             034  Afghanistan                4
# 2                     34             034  Afghanistan                4
# 3                     34             034  Afghanistan                4
# 4                     34             034  Afghanistan                4
# ...                  ...             ...          ...              ...
# 4829                 143             143   Uzbekistan              860
# 4830                 143             143   Uzbekistan              860
# 4831                 143             143   Uzbekistan              860
# 4832                 143             143   Uzbekistan              860
# 4833                 143             143   Uzbekistan              860
#
#      country_code Alpha-3 code Alpha-2 code Subdivision category  \
# 0             004          AFG           AF             province
# 1             004          AFG           AF             province
# 2             004          AFG           AF             province
# 3             004          AFG           AF             province
# 4             004          AFG           AF             province
# ...           ...          ...          ...                  ...
# 4829          860          UZB           UZ               region
# 4830          860          UZB           UZ               region
# 4831          860          UZB           UZ               region
# 4832          860          UZB           UZ                 city
# 4833          860          UZB           UZ               region
#
#      Subdivision name 3166-2 code sub-code country_office_code Office_id
# 0          Badakhshān      AF-BDS      BDS                 001   004-001
# 1             Baghlān      AF-BGL      BGL                 001   004-001
# 2               Balkh      AF-BAL      BAL                 001   004-001
# 3             Bādghīs      AF-BDG      BDG                 001   004-001
# 4              Bāmyān      AF-BAM      BAM                 001   004-001
# ...               ...         ...      ...                 ...       ...
# 4829         Sirdaryo       UZ-SI       SI                 248   860-248
# 4830      Surxondaryo       UZ-SU       SU                 248   860-248
# 4831         Toshkent       UZ-TO       TO                 248   860-248
# 4832         Toshkent       UZ-TK       TK                 248   860-248
# 4833           Xorazm       UZ-XO       XO                 248   860-248
#
# [4834 rows x 17 columns]
