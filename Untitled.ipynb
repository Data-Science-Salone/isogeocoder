# %%
import pandas as pd

# %%
country = pd.read_csv('countryiso.csv')
contenet = pd.read_csv('contenet.csv')
conti = pd.read_csv('continents_sub.csv')

# %%
conti
# Out:
#     M49code_continent  Continet  M49code_Subregions  \
# 0                   2    Africa                  15
# 1                   2    Africa                 202
# 2                   2    Africa                  11
# 3                   2    Africa                  14
# 4                   2    Africa                  17
# 5                   2    Africa                  18
# 6                  10  Americas                   3
# 7                  10  Americas                  21
# 8                  10  Americas                 419
# 9                  10  Americas                   5
# 10                 10  Americas                  13
# 11                 10  Americas                  29
# 12                142      Asia                  30
# 13                142      Asia                  34
# 14                142      Asia                  35
# 15                142      Asia                 143
# 16                142      Asia                 145
# ...

# %%
contenet
# Out:
#                Country or Area Alpha-3 code  M49 Code       Subregions  \
# 0                  Afghanistan          AFG         4    Southern Asia
# 1                Åland Islands          ALA       248  Northern Europe
# 2                      Albania          ALB         8  Southern Europe
# 3                      Algeria          DZA        12  Northern Africa
# 4               American Samoa          ASM        16        Polynesia
# ..                         ...          ...       ...              ...
# 244  Wallis and Futuna Islands          WLF       876        Polynesia
# 245             Western Sahara          ESH       732  Northern Africa
# 246                      Yemen          YEM       887     Western Asia
# 247                     Zambia          ZMB       894   Eastern Africa
# 248                   Zimbabwe          ZWE       716   Eastern Africa
#
#                Region 2 Continent
# 0                   NaN      Asia
# 1                   NaN    Europe
# ...

# %%
countriesd = pd.merge(conti,contenet,on='Subregions',how='right')
countriesd
# Out:
#      M49code_continent Continet  M49code_Subregions     Subregions  \
# 0                142.0     Asia                34.0  Southern Asia
# 1                142.0     Asia                34.0  Southern Asia
# 2                142.0     Asia                34.0  Southern Asia
# 3                142.0     Asia                34.0  Southern Asia
# 4                142.0     Asia                34.0  Southern Asia
# ..                 ...      ...                 ...            ...
# 244              142.0     Asia               143.0   Central Asia
# 245              142.0     Asia               143.0   Central Asia
# 246              142.0     Asia               143.0   Central Asia
# 247              142.0     Asia               143.0   Central Asia
# 248              142.0     Asia               143.0   Central Asia
#
#                 Country or Area Alpha-3 code  M49 Code Region 2 Continent
# 0                   Afghanistan          AFG         4      NaN      Asia
# ...

# %%
countriesd.to_csv('countriesd.csv')

# %%
countries = pd.merge(country,contenet,on='Alpha-3 code',how='left')

# %%
countries
# Out:
#     English short name        French short name Alpha-2 code Alpha-3 code  \
# 0          Afghanistan         Afghanistan (l')           AF          AFG
# 1              Albania             Albanie (l')           AL          ALB
# 2              Algeria             Algérie (l')           DZ          DZA
# 3       American Samoa  Samoa américaines (les)           AS          ASM
# 4              Andorra             Andorre (l')           AD          AND
# ..                 ...                      ...          ...          ...
# 244  Wallis and Futuna         Wallis-et-Futuna           WF          WLF
# 245    Western Sahara*  Sahara occidental (le)*           EH          ESH
# 246              Yemen               Yémen (le)           YE          YEM
# 247             Zambia              Zambie (la)           ZM          ZMB
# 248           Zimbabwe            Zimbabwe (le)           ZW          ZWE
#
#      Numeric            Country or Area  M49 Code         Region 1  \
# ...

# %%
contenet
# Out:
#                Country or Area Alpha-3 code  M49 Code         Region 1  \
# 0                  Afghanistan          AFG         4    Southern Asia
# 1                Åland Islands          ALA       248  Northern Europe
# 2                      Albania          ALB         8  Southern Europe
# 3                      Algeria          DZA        12  Northern Africa
# 4               American Samoa          ASM        16        Polynesia
# ..                         ...          ...       ...              ...
# 244  Wallis and Futuna Islands          WLF       876        Polynesia
# 245             Western Sahara          ESH       732  Northern Africa
# 246                      Yemen          YEM       887     Western Asia
# 247                     Zambia          ZMB       894   Eastern Africa
# 248                   Zimbabwe          ZWE       716   Eastern Africa
#
#                Region 2 Continent
# 0                   NaN      Asia
# 1                   NaN    Europe
# ...
